# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### y=a0+a1x1+a2x2+......

# %%
rng=np.random.RandomState(1)
model=LinearRegression()
x=10*rng.rand(100,3)
y=0.5+np.dot(x,[1.5,-2,1])
model.fit(x,y)
print(model.intercept_)
print(model.coef_)
# Out:
# 0.5000000000000127
# [ 1.5 -2.   1. ]

# %%
xfit_1=np.linspace(0,15,1000)[:,np.newaxis]
xfit_2=np.linspace(0,15,1000)[:,np.newaxis]
xfit_3=np.linspace(0,15,1000)[:,np.newaxis]
xfit=np.hstack((xfit_1,xfit_2,xfit_3))

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(x[:,0],x[:,1],y,c=y)
ax.plot3D(xfit[:,0],xfit[:,1],model.predict(xfit))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y,model.predict(x))
# Out:
# 4.2847473105145017e-29
